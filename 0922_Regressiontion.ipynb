# %% [markdown]
# <a href="https://colab.research.google.com/github/willis1116/Tibame_Machine-Learning/blob/main/0922_Regressiontion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CRIM：人均犯罪率
#
# ZN：25,000平方英尺以上民用土地的比例
#
# INDUS：城镇非零售业商用土地比例
#
# CHAS：是否邻近查尔斯河，1是邻近，0是不邻近
#
# NOX：一氧化氮浓度（千万分之一）
#
# RM：住宅的平均房间数
#
# AGE：自住且建于1940年前的房屋比例
#
# DIS：到5个波士顿就业中心的加权距离
#
# RAD：到高速公路的便捷度指数
#
# TAX：每万元的房产税率
#
# PTRATIO：城镇学生教师比例
#
# B： 1000(Bk − 0.63)2 其中Bk是城镇中黑人比例
#
# LSTAT：低收入人群比例
#
# ans：自住房中位数价格，单位是千元

# %%
from sklearn.datasets import load_boston
import pandas as pd
boston = load_boston()
df = pd.DataFrame(boston['data'], columns=boston['feature_names'])
df['ans'] = boston['target']
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT   ans
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
#進入sklearn就避免使用dataframe, 使用numpy array, df中間會有抽空
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop(['ans'], axis=1), df['ans'], test_size = 0.1)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=5)
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(14, 14))
plot_tree(reg,
     feature_names=boston["feature_names"],
     filled=True)
# Out:
# [Text(339.8971153846154, 697.62, 'LSTAT <= 9.63\nmse = 83.487\nsamples = 455\nvalue = 22.37'),
#  Text(138.96346153846156, 570.78, 'RM <= 6.908\nmse = 77.296\nsamples = 186\nvalue = 29.746'),
#  Text(45.06923076923077, 443.94, 'DIS <= 1.485\nmse = 35.152\nsamples = 125\nvalue = 25.582'),
#  Text(30.04615384615385, 317.1, 'mse = 0.0\nsamples = 4\nvalue = 50.0'),
#  Text(60.0923076923077, 317.1, 'RM <= 6.543\nmse = 15.953\nsamples = 121\nvalue = 24.775'),
#  Text(30.04615384615385, 190.26, 'TAX <= 222.5\nmse = 9.256\nsamples = 76\nvalue = 22.884'),
#  Text(15.023076923076925, 63.42000000000007, 'mse = 14.062\nsamples = 2\nvalue = 32.45'),
#  Text(45.06923076923077, 63.42000000000007, 'mse = 6.586\nsamples = 74\nvalue = 22.626'),
#  Text(90.13846153846154, 190.26, 'TAX <= 269.0\nmse = 11.025\nsamples = 45\nvalue = 27.969'),
#  Text(75.11538461538463, 63.42000000000007, 'mse = 4.854\nsamples = 15\nvalue = 30.607'),
#  Text(105.16153846153847, 63.42000000000007, 'mse = 8.893\nsamples = 30\nvalue = 26.65'),
#  Text(232.85769230769233, 443.94, 'RM <= 7.437\nmse = 55.352\nsamples = 61\nvalue = 38.277'),
#  Text(180.27692307692308, 317.1, 'DIS <= 1.886\nmse = 19.676\nsamples = 36\nvalue = 33.953'),
#  Text(150.23076923076925, 190.26, 'CHAS <= 0.5\nmse = 18.923\nsamples = 2\nvalue = 45.65'),
#  Text(135.20769230769233, 63.42000000000007, 'mse = 0.0\nsamples = 1\nvalue = 41.3'),
#  Text(165.25384615384618, 63.42000000000007, 'mse = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(210.32307692307694, 190.26, 'TAX <= 267.0\nmse = 11.198\nsamples = 34\nvalue = 33.265'),
#  Text(195.3, 63.42000000000007, 'mse = 2.496\nsamples = 15\nvalue = 35.267'),
#  Text(225.34615384615387, 63.42000000000007, 'mse = 12.407\nsamples = 19\nvalue = 31.684'),
#  Text(285.4384615384616, 317.1, 'NOX <= 0.683\nmse = 41.024\nsamples = 25\nvalue = 44.504'),
#  Text(270.41538461538465, 190.26, 'PTRATIO <= 17.6\nmse = 20.557\nsamples = 24\nvalue = 45.446'),
#  Text(255.39230769230772, 63.42000000000007, 'mse = 13.85\nsamples = 19\nvalue = 46.863'),
#  Text(285.4384615384616, 63.42000000000007, 'mse = 9.406\nsamples = 5\nvalue = 40.06'),
#  Text(300.4615384615385, 190.26, 'mse = -0.0\nsamples = 1\nvalue = 21.9'),
#  Text(540.8307692307693, 570.78, 'LSTAT <= 16.085\nmse = 24.149\nsamples = 269\nvalue = 17.271'),
#  Text(420.6461538461539, 443.94, 'B <= 116.025\nmse = 10.861\nsamples = 136\nvalue = 20.277'),
#  Text(360.55384615384617, 317.1, 'CRIM <= 9.346\nmse = 8.353\nsamples = 7\nvalue = 14.014'),
#  Text(330.50769230769237, 190.26, 'TAX <= 393.5\nmse = 1.722\nsamples = 3\nvalue = 16.767'),
#  Text(315.48461538461544, 63.42000000000007, 'mse = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(345.5307692307693, 63.42000000000007, 'mse = 0.062\nsamples = 2\nvalue = 15.85'),
#  Text(390.6, 190.26, 'DIS <= 1.638\nmse = 3.383\nsamples = 4\nvalue = 11.95'),
#  Text(375.5769230769231, 63.42000000000007, 'mse = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(405.62307692307695, 63.42000000000007, 'mse = 0.376\nsamples = 3\nvalue = 10.933'),
#  Text(480.7384615384616, 317.1, 'TAX <= 278.0\nmse = 8.753\nsamples = 129\nvalue = 20.617'),
#  Text(450.69230769230774, 190.26, 'RM <= 6.618\nmse = 11.965\nsamples = 25\nvalue = 23.136'),
#  Text(435.6692307692308, 63.42000000000007, 'mse = 5.867\nsamples = 22\nvalue = 22.182'),
#  Text(465.71538461538466, 63.42000000000007, 'mse = 1.042\nsamples = 3\nvalue = 30.133'),
#  Text(510.78461538461545, 190.26, 'LSTAT <= 11.67\nmse = 6.089\nsamples = 104\nvalue = 20.012'),
#  Text(495.7615384615385, 63.42000000000007, 'mse = 5.097\nsamples = 35\nvalue = 21.457'),
#  Text(525.8076923076924, 63.42000000000007, 'mse = 4.994\nsamples = 69\nvalue = 19.278'),
#  Text(661.0153846153847, 443.94, 'NOX <= 0.603\nmse = 19.041\nsamples = 133\nvalue = 14.196'),
#  Text(600.923076923077, 317.1, 'PTRATIO <= 20.95\nmse = 13.487\nsamples = 44\nvalue = 17.695'),
#  Text(570.8769230769232, 190.26, 'RM <= 6.843\nmse = 12.183\nsamples = 36\nvalue = 18.561'),
#  Text(555.8538461538462, 63.42000000000007, 'mse = 10.183\nsamples = 35\nvalue = 18.306'),
#  Text(585.9000000000001, 63.42000000000007, 'mse = 0.0\nsamples = 1\nvalue = 27.5'),
#  Text(630.9692307692309, 190.26, 'CRIM <= 1.043\nmse = 0.805\nsamples = 8\nvalue = 13.8'),
#  Text(615.946153846154, 63.42000000000007, 'mse = 0.482\nsamples = 3\nvalue = 14.767'),
#  Text(645.9923076923078, 63.42000000000007, 'mse = 0.102\nsamples = 5\nvalue = 13.22'),
#  Text(721.1076923076923, 317.1, 'LSTAT <= 19.645\nmse = 12.741\nsamples = 89\nvalue = 12.466'),
#  Text(691.0615384615386, 190.26, 'CRIM <= 11.663\nmse = 5.961\nsamples = 36\nvalue = 15.314'),
#  Text(676.0384615384617, 63.42000000000007, 'mse = 5.09\nsamples = 34\nvalue = 15.559'),
#  Text(706.0846153846155, 63.42000000000007, 'mse = 2.402\nsamples = 2\nvalue = 11.15'),
#  Text(751.1538461538462, 190.26, 'TAX <= 551.5\nmse = 8.098\nsamples = 53\nvalue = 10.532'),
#  Text(736.1307692307693, 63.42000000000007, 'mse = 2.742\nsamples = 8\nvalue = 14.262'),
#  Text(766.1769230769231, 63.42000000000007, 'mse = 6.136\nsamples = 45\nvalue = 9.869')]

# %%
from sklearn.metrics import r2_score
pre = reg.predict(x_test)
r2_score(pre, y_test)
# Out:
# 0.8623246618418645

# %% [markdown]
# MSE 可以做為衡量regrassion 結果的預測準測度
#
# RMSE MSE開根號
#
# MAE
#
# r square score (有Normalization)
