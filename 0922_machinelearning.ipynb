# %% [markdown]
# <a href="https://colab.research.google.com/github/willis1116/Tibame_Machine-Learning/blob/main/0922_machinelearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import pandas as pd
iris = load_iris()
df = pd.DataFrame(iris['data'], columns=iris['feature_names'])
df['ans'] = iris['target']

# %%
#進入sklearn就避免使用dataframe, 使用numpy array, df中間會有抽空
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop(['ans'], axis=1), df['ans'], test_size = 0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(14, 14))
plot_tree(clf,
     feature_names=iris["feature_names"],
     class_names=iris["target_names"],
     filled=True)
# Out:
# [Text(390.6, 684.9359999999999, 'petal width (cm) <= 0.8\ngini = 0.666\nsamples = 135\nvalue = [43, 46, 46]\nclass = versicolor'),
#  Text(330.50769230769237, 532.728, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]\nclass = setosa'),
#  Text(450.69230769230774, 532.728, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 92\nvalue = [0, 46, 46]\nclass = versicolor'),
#  Text(240.3692307692308, 380.52, 'petal length (cm) <= 4.95\ngini = 0.15\nsamples = 49\nvalue = [0, 45, 4]\nclass = versicolor'),
#  Text(120.1846153846154, 228.312, 'petal width (cm) <= 1.65\ngini = 0.044\nsamples = 44\nvalue = [0, 43, 1]\nclass = versicolor'),
#  Text(60.0923076923077, 76.10399999999993, 'gini = 0.0\nsamples = 43\nvalue = [0, 43, 0]\nclass = versicolor'),
#  Text(180.27692307692308, 76.10399999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(360.55384615384617, 228.312, 'petal width (cm) <= 1.55\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]\nclass = virginica'),
#  Text(300.4615384615385, 76.10399999999993, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(420.6461538461539, 76.10399999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(661.0153846153847, 380.52, 'petal length (cm) <= 4.85\ngini = 0.045\nsamples = 43\nvalue = [0, 1, 42]\nclass = virginica'),
#  Text(600.923076923077, 228.312, 'sepal length (cm) <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(540.8307692307693, 76.10399999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(661.0153846153847, 76.10399999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(721.1076923076923, 228.312, 'gini = 0.0\nsamples = 40\nvalue = [0, 0, 40]\nclass = virginica')]

# %% [markdown]
# gini index (猜錯的機率)
#
# $GiniIndex = P_{1}(1-P_{1}) + P_{2}(1-P_{2}) = 1- P_{1}^2 - P_{2}^2$
#
# 我猜p1他出現p2的機會 + 我猜p2他出現p1的機會
